# %%
import pandas as pd
import sqlite3
import numpy as np

# %%
conn = sqlite3.connect(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\APOE-SLAT\nlp_annotator-dev\app\db.sqlite3")

# %%
sd = sqlite3.connect(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\APOE-SLAT\nlp_annotator-dev\app\Previous-DBs\db_SD.sqlite3")

# %%
always_regex_matches = pd.read_sql("SELECT * FROM gui_sentencealwaysregex", conn)

# %%
always_regex_matches
# Out:
# Empty DataFrame
# Columns: [id, AlwaysRegex_id, Sentence_id]
# Index: []

# %%
sd_always_regex_matches = pd.read_sql("SELECT * FROM gui_sentencealwaysregex", sd)

# %%
sd_always_regex_matches
# Out:
#         id  AlwaysRegex_id  Sentence_id
# 0       53               2          377
# 1       54               2        20965
# 2       55               2          532
# 3       56               2        29481
# 4       57               2         2909
# ...    ...             ...          ...
# 8628  9618              37       176918
# 8629  9619              37       184583
# 8630  9620              37       248788
# 8631  9621              38         3086
# 8632  9622              38       193487
#
# [8633 rows x 3 columns]

# %%
sentence_ids = sd_always_regex_matches["Sentence_id"].to_list()

# %%
sd_sentence_annotation = pd.read_sql("SELECT * FROM gui_sentenceannotation", sd)

# %%
sd_sentence_annotation.head()
# Out:
#    id Label  Annotator_id  Sentence_id
# 0   1   NTR             3         2990
# 1   2   YES             3         3003
# 2   3   YES             3         3009
# 3   4   NTR             3         3013
# 4   5   NTR             3         3035

# %%
sentence_ids.extend(sd_sentence_annotation["Sentence_id"].to_list())

# %%
len(sentence_ids) # 8633 + 23
# Out:
# 8656

# %%
sentences = pd.read_sql("SELECT * FROM gui_sentence", conn)

# %%
sentences
# Out:
#          index      id                                           Contents  \
# 0            0       1  "ession alone in the meta-analysis. We discuss...
# 1            2       3  " ------- l obstruction ASSOCIATED DIAGNOSES S...
# 2            3       4  " -------  (156 lb) 09/19/17 71.4 kg (157 lb 6...
# 3            4       5  "ut answer. Optho notes from recent outpatient...
# 4            5       6  "hat would be more consistent. Has been alert/...
# ...        ...     ...                                                ...
# 270563  279219  279220  "''she took a break' and wants to discuss with...
# 270564  279220  279221  "'all of her medications, including aspirin. D...
# 270565  279221  279222  "'Patient, Chart, daughter Olga Mode of contac...
# 270566  279222  279223  "'Patient, Chart, daughter Olga Mode of contac...
# 270567  279223  279224  "'cyanosis or edema. Neurological exam: Nonfoc...
#
#         Note_id already_annotated
# 0             1                 N
# 1             3                 N
# 2             4                 N
# 3             5                 N
# 4             6                 N
# ...         ...               ...
# 270563   274442                 N
# 270564   274443                 N
# 270565   274444                 N
# 270566   274445                 N
# 270567   274446                 N
#
# [270568 rows x 5 columns]

# %%
# Verifiying that all sentence ids that were fetched actually exist inside entire sentence table
for i in range(len(sentence_ids)):
    filtered = sentences[sentences["id"] == sentence_ids[i]]
    if(len(filtered) == 0):
        print("Sentence Id", sentence_ids[i])

# %%
sentences["already_annotated"] = np.where(sentences["id"].isin(sentence_ids), 'Y', 'N')
sentences_filtered = sentences[sentences["already_annotated"] == "N"]

# %%
sentences_filtered
# Out:
#          index      id                                           Contents  \
# 0            0       1  "ession alone in the meta-analysis. We discuss...
# 1            2       3  " ------- l obstruction ASSOCIATED DIAGNOSES S...
# 2            3       4  " -------  (156 lb) 09/19/17 71.4 kg (157 lb 6...
# 3            4       5  "ut answer. Optho notes from recent outpatient...
# 4            5       6  "hat would be more consistent. Has been alert/...
# ...        ...     ...                                                ...
# 270563  279219  279220  "''she took a break' and wants to discuss with...
# 270564  279220  279221  "'all of her medications, including aspirin. D...
# 270565  279221  279222  "'Patient, Chart, daughter Olga Mode of contac...
# 270566  279222  279223  "'Patient, Chart, daughter Olga Mode of contac...
# 270567  279223  279224  "'cyanosis or edema. Neurological exam: Nonfoc...
#
#         Note_id already_annotated
# 0             1                 N
# 1             3                 N
# 2             4                 N
# 3             5                 N
# 4             6                 N
# ...         ...               ...
# 270563   274442                 N
# 270564   274443                 N
# 270565   274444                 N
# 270566   274445                 N
# 270567   274446                 N
#
# [270568 rows x 5 columns]

# %%
sentences_filtered.drop(columns = ['already_annotated'])
# Out:
#          index      id                                           Contents  \
# 0            0       1  "ession alone in the meta-analysis. We discuss...
# 1            2       3  " ------- l obstruction ASSOCIATED DIAGNOSES S...
# 2            3       4  " -------  (156 lb) 09/19/17 71.4 kg (157 lb 6...
# 3            4       5  "ut answer. Optho notes from recent outpatient...
# 4            5       6  "hat would be more consistent. Has been alert/...
# ...        ...     ...                                                ...
# 270563  279219  279220  "''she took a break' and wants to discuss with...
# 270564  279220  279221  "'all of her medications, including aspirin. D...
# 270565  279221  279222  "'Patient, Chart, daughter Olga Mode of contac...
# 270566  279222  279223  "'Patient, Chart, daughter Olga Mode of contac...
# 270567  279223  279224  "'cyanosis or edema. Neurological exam: Nonfoc...
#
#         Note_id
# 0             1
# 1             3
# 2             4
# 3             5
# 4             6
# ...         ...
# 270563   274442
# 270564   274443
# 270565   274444
# 270566   274445
# 270567   274446
#
# [270568 rows x 4 columns]

# %%
sentences_filtered.to_sql("gui_sentence", conn, if_exists = "replace")

# %%
test = sqlite3.connect(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\APOE-SLAT\nlp_annotator-dev\app\db_test.sqlite3")

# %%
x = pd.read_sql("SELECT * FROM gui_sentence", test)

# %%
x
# Out:
#             id                                           Contents  Note_id
# 0            1  ession alone in the meta-analysis. We discusse...        1
# 1            2   ------- sis over her R bra strap, which was i...        2
# 2            3   ------- l obstruction ASSOCIATED DIAGNOSES Sm...        3
# 3            4   -------  (156 lb) 09/19/17 71.4 kg (157 lb 6....        4
# 4            5  ut answer. Optho notes from recent outpatient ...        5
# ...        ...                                                ...      ...
# 279219  279220  ''she took a break' and wants to discuss with ...   274442
# 279220  279221  'all of her medications, including aspirin. De...   274443
# 279221  279222  'Patient, Chart, daughter Olga Mode of contact...   274444
# 279222  279223  'Patient, Chart, daughter Olga Mode of contact...   274445
# 279223  279224  'cyanosis or edema. Neurological exam: Nonfoca...   274446
#
# [279224 rows x 3 columns]
