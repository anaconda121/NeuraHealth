# %%
import pandas as pd
import pandas.io.sql as psql
import os
import sys
from datetime import date
current_date = date.today()
#%load_ext autotime
import re
import csv
import pandas as pd
import numpy as np
import os
from glob import glob
from tqdm import tqdm
import matplotlib.pyplot as plt
#from matplotlib_venn import venn2, venn3
import warnings
import time
import datetime as dt
import itertools
from more_itertools import unique_everseen
warnings.filterwarnings("ignore")
#import pandasql as ps
import seaborn as sns
import json
from ast import literal_eval
import ast

# %%
example = pd.read_excel(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\SLAT\memory_disorder_SLAT\regex_dataset.xlsx", sheet_name = "Sheet1")

# %%
example
# Out:
#        PatientID           MRN         EMPI  PatientEncounterID  \
# 0       Z6708893  1.004451e+10  100100942.0        3.115772e+09
# 1       Z7766129  1.002544e+10  100240713.0        3.116814e+09
# 2       Z9132953  2.511694e+06  105740146.0        3.107134e+09
# 3       Z9132953  2.511694e+06  105740146.0        3.107134e+09
# 4       Z9132953  2.511694e+06  105740146.0        3.107134e+09
# ...          ...           ...          ...                 ...
# 23711   Z9833197  7.711140e+05  102405601.0        3.115574e+09
# 23712  Z10910426  2.263407e+07  104760040.0        3.110203e+09
# 23713   Z8133252  4.131140e+05  106467899.0        3.076173e+09
# 23714   Z8133252  4.131140e+05  106467899.0        3.076173e+09
# 23715   Z7386070  6.209290e+05  100190744.0        3.110888e+09
#
#       InpatientNoteTypeDSC      NoteID  NoteCSNID  ContactDTS  \
# 0           Progress Notes  1000021019  955432079  2016-04-28
# 1                      H&P  1000431290  954962537  2016-04-28
# 2           Progress Notes  1001733204  956198896  2016-04-29
# 3           Progress Notes  1001733204  956198896  2016-04-29
# 4           Progress Notes  1001733204  956198896  2016-04-29
# ...                    ...         ...        ...         ...
# 23711    ED Provider Notes   978113347  934708722  2016-04-14
# 23712       Progress Notes   978789346  934607317  2016-04-14
# 23713       Progress Notes   993123218  948167998  2016-04-25
# 23714       Progress Notes   993123218  948167998  2016-04-25
# 23715       Progress Notes   994332585  951349633  2016-04-26
#
#                                                  NoteTXT  \
# 0      ----------------------------------------------...
# 1      ----------------------------------------------...
# 2      ----------------------------------------------...
# 3      ----------------------------------------------...
# 4      ----------------------------------------------...
# ...                                                  ...
# 23711  ----------------------------------------------...
# 23712  ----------------------------------------------...
# 23713  ----------------------------------------------...
# 23714  ----------------------------------------------...
# 23715  ----------------------------------------------...
#
#                                               regex_sent  \
# 0      "Visit Other Routine general medical examinati...
# 1      "\u2022 Doxepin Other (See Comments) vivid dre...
# 2      "accident moving next year due to extra bedroo...
# 3      "techniques discuss again correlations long te...
# 4      "benzo rxs 4/98, 9/97, 5/04 Family history: -m...
# ...                                                  ...
# 23711  "and Coronary artery disease. who presents wit...
# 23712  "or recreational drug use. Family History: Mot...
# 23713  "Family History Problem Relation Age of Onset ...
# 23714  "Age of Onset \u2022 Rheumatoid arthritis Moth...
# 23715  "in the past. PF4 on 4/5/15 was negative at 0....
#
#                                           regex_match
# 0                                   ["memory change"]
# 1                                  ["memory problem"]
# 2                                        ["dementia"]
# 3                                        ["dementia"]
# 4                                        ["dementia"]
# ...                                               ...
# 23711                               ["mild dementia"]
# 23712                         ["Alzheimer's disease"]
# 23713  ["Alzheimer's disease", "Alzheimer's disease"]
# 23714  ["Alzheimer's disease", "Alzheimer's disease"]
# 23715                                    ["Dementia"]
#
# [23716 rows x 11 columns]

# %%
example.columns
# Out:
# Index(['PatientID', 'MRN', 'EMPI', 'PatientEncounterID',
#        'InpatientNoteTypeDSC', 'NoteID', 'NoteCSNID', 'ContactDTS', 'NoteTXT',
#        'regex_sent', 'regex_match'],
#       dtype='object')

# %% [markdown]
# # Padded Matches

# %%
# df1 = pd.read_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\1\Padded_Matches\apoe_1_padded_matches.csv")
# df2 = pd.read_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\2\Padded_Matches\apoe_2_padded_matches.csv")
# df3 = pd.read_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\3\Padded_Matches\apoe_3_padded_matches.csv")
# df4 = pd.read_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\4\Padded_Matches\apoe_4_padded_matches.csv")
# df5 = pd.read_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\5\Padded_Matches\apoe_5_padded_matches.csv")

# %%
# len(df1), len(df2), len(df3), len(df4), len(df5)
# Out:
# (50577, 45719, 46649, 48325, 48359)

# %%
frames = [df1, df2,df3, df4, df5]
df = pd.concat(frames)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'Unnamed: 0.1.1.1',
#        'EMPI', 'MRN', 'PatientID', 'PatientEncounterID', 'ContactDTS',
#        'EncounterTypeDSC', 'NoteID', 'InpatientNoteTypeDSC', 'buckets',
#        'NoteCSNID', 'LineNBR', 'NoteTXT', 'regex_location', 'regex_sent',
#        'regex_match', 'match_count', 'pruned_regex_location',
#        'merged_row_location', 'merged_regex_sent', 'merged_regex_match',
#        'sequence_level_regex_location', 'sequence_level_regex_match',
#        'char_count', 'padded_merged_row_location', 'padded_merged_regex_sent',
#        'padded_char_count', 'note_char_count'],
#       dtype='object')

# %%
df = df.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'Unnamed: 0.1.1.1', 'EncounterTypeDSC'])
df.head()
# Out:
#         EMPI          MRN PatientID  PatientEncounterID  \
# 0  100000272  10040002098  Z6352398        3.076070e+09
# 1  100000272  10040002098  Z6352398        3.076214e+09
# 2  100000272  10040002098  Z6352398        3.242118e+09
# 3  100000272  10040002098  Z6352398        3.322836e+09
# 4  100000272  10040002098  Z6352398        3.325561e+09
#
#                     ContactDTS      NoteID InpatientNoteTypeDSC  buckets  \
# 0  2015-06-17 00:00:00.0000000   471433064       Progress Notes        1
# 1  2015-07-16 00:00:00.0000000   513142600       Progress Notes        1
# 2  2019-03-14 00:00:00.0000000  2370049295       Progress Notes        1
# 3  2020-12-04 00:00:00.0000000  4959788710       Progress Notes        1
# 4  2020-09-18 00:00:00.0000000  4570521668       Progress Notes        1
#
#       NoteCSNID  LineNBR  ...                        merged_row_location  \
# 0  4.532520e+08      1.0  ...                             [(5750, 5958)]
# 1  4.924833e+08      1.0  ...                             [(3543, 3749)]
# 2  2.338373e+09      1.0  ...                             [(8641, 8849)]
# 3  4.951007e+09      1.0  ...  [(948, 1152), (4778, 4987), (5004, 5331)]
# 4  4.558686e+09      1.0  ...               [(5367, 5576), (5593, 5812)]
#
#                                    merged_regex_sent  \
# 0  ------- ncer. She passed secondary to this. He...
# 1  ------- a. Skin: No rashes or lesions. Neurolo...
# 2  ------- ractures, obesity, insulin resistance,...
# 3  -------  accept for this week when he ran out ...
# 4  ------- ue Tylenol 1g q8 as needed - If pain w...
#
#                    merged_regex_match  \
# 0                       [' cerebral']
# 1                         [' memory']
# 2                       [' dementia']
# 3  [' moca', ' cognition', ' memory']
# 4           [' cognition', ' memory']
#
#                        sequence_level_regex_location  \
# 0                                       [(108, 116)]
# 1                                       [(108, 114)]
# 2                                       [(108, 116)]
# 3  [(321, 330), (549, 558), (539, 545), (108, 112...
# 4               [(108, 117), (336, 345), (326, 332)]
#
#         sequence_level_regex_match char_count  \
# 0                     ['cerebral']        213
# 1                       ['memory']        210
# 2                     ['dementia']        208
# 3  ['cognition', 'memory', 'moca']        764
# 4          ['cognition', 'memory']        441
#
#                   padded_merged_row_location  \
# 0                               (5457, 6251)
# 1                               (3248, 4044)
# 2                               (8345, 9145)
# 3  [(930, 1152), (4778, 4987), (5004, 5349)]
# 4               [(5188, 5576), (5593, 5991)]
#
#                             padded_merged_regex_sent padded_char_count  \
# 0  ked at HMS in the department of psychobiology ...               794
# 1  or lymphadenopathy. Chest: Clear to auscultati...               796
# 2  ession alone in the meta-analysis. We discusse...               800
# 3   ------- ing tylenol really accept for this we...               803
# 4   ------- in is related to cancer. Reassuringly...               804
#
#   note_char_count
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Computing Matches For Padded Sequences

# %%
regex = pd.read_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\APOE-SLAT\EDA\Getting_Data\keywords.csv")

# %%
k = regex["REGEX"].to_list()
c = regex["CASE"].to_list()
p_list = []

for i in range(len(k)):
    if (c[i] == 0):
        p_list.append(re.compile(k[i][5:], re.IGNORECASE))
    elif (c[i] == 1):
        p_list.append(re.compile(k[i]))
print(p_list)
# Out:
# [re.compile('\\bdementia\\b', re.IGNORECASE), re.compile('\\bcognition\\b', re.IGNORECASE), re.compile('\\bmemory\\b', re.IGNORECASE), re.compile('\\bMMSE\\b', re.IGNORECASE), re.compile('\\bMOCA\\b', re.IGNORECASE), re.compile('\\bAlzheimer\\b', re.IGNORECASE), re.compile('\\bcognitive\\s*impairment\\b', re.IGNORECASE), re.compile('(?-i:)\\bMCI\\b'), re.compile('\\bcerebellar\\b', re.IGNORECASE), re.compile('\\bNeurocognitive\\b', re.IGNORECASE), re.compile('\\blewy\\b', re.IGNORECASE), re.compile("\\bpick's\\b", re.IGNORECASE), re.compile('\\bCorticobasal\\b', re.IGNORECASE), re.compile('\\bcerebral\\b', re.IGNORECASE), re.compile('\\bcerebrovascular\\b', re.IGNORECASE), re.compile('\\bamnesia\\b', re.IGNORECASE), re.compile('(?-i:)\\bAD\\b'), re.compile('(?-i:)\\bLBD\\b')]

# %%
l = []
for note in tqdm(df["padded_merged_regex_sent"]):
    curr = []
    for p in (p_list):
        m = list(set(re.findall(p, note)))
        m = list(set(map(str.lower, m)))
        if (m != []):
            curr.append("".join(m))
    #print(curr)
    #print(l)
    l.append((curr))

df["padded_regex_match"] = l
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 239629/239629 [02:28<00:00, 1616.42it/s]

# %%
df
# Out:
#             EMPI          MRN  PatientID  PatientEncounterID  \
# 0      100000272  10040002098   Z6352398        3.076070e+09
# 1      100000272  10040002098   Z6352398        3.076214e+09
# 2      100000272  10040002098   Z6352398        3.242118e+09
# 3      100000272  10040002098   Z6352398        3.322836e+09
# 4      100000272  10040002098   Z6352398        3.325561e+09
# ...          ...          ...        ...                 ...
# 48354  113722742  10127721883  Z16337903        3.215952e+09
# 48355  113722742  10127721883  Z16337903        3.217899e+09
# 48356  113722742  10127721883  Z16337903        3.223494e+09
# 48357  113722742  10127721883  Z16337903        3.329813e+09
# 48358  113727131  10127767464  Z16342458        3.194125e+09
#
#                         ContactDTS      NoteID InpatientNoteTypeDSC  buckets  \
# 0      2015-06-17 00:00:00.0000000   471433064       Progress Notes        1
# 1      2015-07-16 00:00:00.0000000   513142600       Progress Notes        1
# 2      2019-03-14 00:00:00.0000000  2370049295       Progress Notes        1
# 3      2020-12-04 00:00:00.0000000  4959788710       Progress Notes        1
# 4      2020-09-18 00:00:00.0000000  4570521668       Progress Notes        1
# ...                            ...         ...                  ...      ...
# 48354  2018-09-05 00:00:00.0000000  2123364929       Progress Notes        5
# 48355  2018-10-03 00:00:00.0000000  2161398176       Progress Notes        5
# 48356  2018-10-31 00:00:00.0000000  2198013886       Progress Notes        5
# 48357  2020-11-04 00:00:00.0000000  4806472815       Progress Notes        5
# 48358  2018-03-20 00:00:00.0000000  1935969876    Discharge Summary        5
#
#           NoteCSNID  LineNBR  ...  \
# 0      4.532520e+08      1.0  ...
# 1      4.924833e+08      1.0  ...
# 2      2.338373e+09      1.0  ...
# 3      4.951007e+09      1.0  ...
# 4      4.558686e+09      1.0  ...
# ...             ...      ...  ...
# 48354  2.085143e+09      1.0  ...
# 48355  2.124284e+09      1.0  ...
# 48356  2.161922e+09      1.0  ...
# 48357  4.806423e+09      1.0  ...
# 48358  1.892266e+09      1.0  ...
#
#                                        merged_regex_sent  \
# 0      ------- ncer. She passed secondary to this. He...
# 1      ------- a. Skin: No rashes or lesions. Neurolo...
# 2      ------- ractures, obesity, insulin resistance,...
# 3      -------  accept for this week when he ran out ...
# 4      ------- ue Tylenol 1g q8 as needed - If pain w...
# ...                                                  ...
# 48354  ------- INDINGS: The brain parenchyma demonstr...
# 48355  ------- ROS performed and are negative. The pa...
# 48356  -------  (R) gait status, as well as getting u...
# 48357  ------- her lesions. Normal turgor. [Psych]: A...
# 48358  ------- rtably Abdomen: soft, NT, ND GU: voidi...
#
#                        merged_regex_match  \
# 0                           [' cerebral']
# 1                             [' memory']
# 2                           [' dementia']
# 3      [' moca', ' cognition', ' memory']
# 4               [' cognition', ' memory']
# ...                                   ...
# 48354        [' cerebral', ' cerebellar']
# 48355           [' cognition', ' memory']
# 48356                      [' cognition']
# 48357                      [' cognition']
# 48358                      [' cognition']
#
#                            sequence_level_regex_location  \
# 0                                           [(108, 116)]
# 1                                           [(108, 114)]
# 2                                           [(108, 116)]
# 3      [(321, 330), (549, 558), (539, 545), (108, 112...
# 4                   [(108, 117), (336, 345), (326, 332)]
# ...                                                  ...
# 48354   [(108, 118), (544, 554), (327, 335), (579, 587)]
# 48355                           [(108, 117), (326, 332)]
# 48356                                       [(108, 117)]
# 48357                                       [(108, 117)]
# 48358                                       [(108, 117)]
#
#             sequence_level_regex_match  char_count  \
# 0                         ['cerebral']         213
# 1                           ['memory']         210
# 2                         ['dementia']         208
# 3      ['cognition', 'memory', 'moca']         764
# 4              ['cognition', 'memory']         441
# ...                                ...         ...
# 48354       ['cerebellar', 'cerebral']         682
# 48355          ['cognition', 'memory']         423
# 48356                    ['cognition']         215
# 48357                    ['cognition']         190
# 48358                    ['cognition']         207
#
#                              padded_merged_row_location  \
# 0                                          (5457, 6251)
# 1                                          (3248, 4044)
# 2                                          (8345, 9145)
# 3             [(930, 1152), (4778, 4987), (5004, 5349)]
# 4                          [(5188, 5576), (5593, 5991)]
# ...                                                 ...
# 48354  [(10320, 10589), (10838, 11046), (11051, 11353)]
# 48355                    [(3531, 3928), (10689, 11083)]
# 48356                                    [(1690, 2483)]
# 48357                                    [(3071, 3871)]
# 48358                                    [(8788, 9589)]
#
#                                 padded_merged_regex_sent padded_char_count  \
# 0      ked at HMS in the department of psychobiology ...               794
# 1      or lymphadenopathy. Chest: Clear to auscultati...               796
# 2      ession alone in the meta-analysis. We discusse...               800
# 3       ------- ing tylenol really accept for this we...               803
# 4       ------- in is related to cancer. Reassuringly...               804
# ...                                                  ...               ...
# 48354   -------  pulse sequence(s). MRA of the neck w...               806
# 48355   ------- ONITORING LT4: TSH Date Value Ref Ran...               809
# 48356  e patient felt much more comfortable with and ...               793
# 48357  y Social History Narrative Divorced, 1 daughte...               800
# 48358   0737) O2 Device: None (Room air) (04/12/18 07...               801
#
#       note_char_count         padded_regex_match
# 0                 NaN                 [cerebral]
# 1                 NaN                   [memory]
# 2                 NaN                 [dementia]
# 3                 NaN  [cognition, memory, moca]
# 4                 NaN        [cognition, memory]
# ...               ...                        ...
# 48354         17293.0     [cerebellar, cerebral]
# 48355         12288.0        [cognition, memory]
# 48356          4006.0                [cognition]
# 48357          3872.0                [cognition]
# 48358         10023.0                [cognition]
#
# [239629 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['EMPI', 'MRN', 'PatientID', 'PatientEncounterID', 'ContactDTS',
#        'NoteID', 'InpatientNoteTypeDSC', 'buckets', 'NoteCSNID', 'LineNBR',
#        'NoteTXT', 'regex_location', 'regex_sent', 'regex_match', 'match_count',
#        'pruned_regex_location', 'merged_row_location', 'merged_regex_sent',
#        'merged_regex_match', 'sequence_level_regex_location',
#        'sequence_level_regex_match', 'char_count',
#        'padded_merged_row_location', 'padded_merged_regex_sent',
#        'padded_char_count', 'note_char_count', 'padded_regex_match'],
#       dtype='object')

# %% [markdown]
# ## Dropping Rest of Columns

# %%
example.columns
# Out:
# Index(['PatientID', 'MRN', 'EMPI', 'PatientEncounterID',
#        'InpatientNoteTypeDSC', 'NoteID', 'NoteCSNID', 'ContactDTS', 'NoteTXT',
#        'regex_sent', 'regex_match'],
#       dtype='object')

# %%
df = df.drop(columns = ['buckets', 'LineNBR', 'regex_location', 'regex_sent', 'regex_match', 'match_count','pruned_regex_location', 'merged_row_location', 'merged_regex_sent','merged_regex_match', 'sequence_level_regex_location','sequence_level_regex_match', 'char_count','padded_merged_row_location', 'padded_char_count',])

# %%
df = df.drop(columns = ['note_char_count'])

# %%
df.columns
# Out:
# Index(['EMPI', 'MRN', 'PatientID', 'PatientEncounterID', 'ContactDTS',
#        'NoteID', 'InpatientNoteTypeDSC', 'NoteCSNID', 'NoteTXT',
#        'padded_merged_regex_sent', 'padded_regex_match'],
#       dtype='object')

# %%
df.columns = ['EMPI', 'MRN', 'PatientID', 'PatientEncounterID', 'ContactDTS',
       'NoteID', 'InpatientNoteTypeDSC', 'NoteCSNID', 'NoteTXT', 'regex_sent', 'regex_match']

# %%
df
# Out:
#             EMPI          MRN  PatientID  PatientEncounterID  \
# 0      100000272  10040002098   Z6352398        3.076070e+09
# 1      100000272  10040002098   Z6352398        3.076214e+09
# 2      100000272  10040002098   Z6352398        3.242118e+09
# 3      100000272  10040002098   Z6352398        3.322836e+09
# 4      100000272  10040002098   Z6352398        3.325561e+09
# ...          ...          ...        ...                 ...
# 48354  113722742  10127721883  Z16337903        3.215952e+09
# 48355  113722742  10127721883  Z16337903        3.217899e+09
# 48356  113722742  10127721883  Z16337903        3.223494e+09
# 48357  113722742  10127721883  Z16337903        3.329813e+09
# 48358  113727131  10127767464  Z16342458        3.194125e+09
#
#                         ContactDTS      NoteID InpatientNoteTypeDSC  \
# 0      2015-06-17 00:00:00.0000000   471433064       Progress Notes
# 1      2015-07-16 00:00:00.0000000   513142600       Progress Notes
# 2      2019-03-14 00:00:00.0000000  2370049295       Progress Notes
# 3      2020-12-04 00:00:00.0000000  4959788710       Progress Notes
# 4      2020-09-18 00:00:00.0000000  4570521668       Progress Notes
# ...                            ...         ...                  ...
# 48354  2018-09-05 00:00:00.0000000  2123364929       Progress Notes
# 48355  2018-10-03 00:00:00.0000000  2161398176       Progress Notes
# 48356  2018-10-31 00:00:00.0000000  2198013886       Progress Notes
# 48357  2020-11-04 00:00:00.0000000  4806472815       Progress Notes
# 48358  2018-03-20 00:00:00.0000000  1935969876    Discharge Summary
#
#           NoteCSNID                                            NoteTXT  \
# 0      4.532520e+08  ----------------------------------------------...
# 1      4.924833e+08  ----------------------------------------------...
# 2      2.338373e+09  ----------------------------------------------...
# 3      4.951007e+09  ----------------------------------------------...
# 4      4.558686e+09  ----------------------------------------------...
# ...             ...                                                ...
# 48354  2.085143e+09  ----------------------------------------------...
# 48355  2.124284e+09  ----------------------------------------------...
# 48356  2.161922e+09  ----------------------------------------------...
# 48357  4.806423e+09  ----------------------------------------------...
# 48358  1.892266e+09  ----------------------------------------------...
#
#                                               regex_sent  \
# 0      ked at HMS in the department of psychobiology ...
# 1      or lymphadenopathy. Chest: Clear to auscultati...
# 2      ession alone in the meta-analysis. We discusse...
# 3       ------- ing tylenol really accept for this we...
# 4       ------- in is related to cancer. Reassuringly...
# ...                                                  ...
# 48354   -------  pulse sequence(s). MRA of the neck w...
# 48355   ------- ONITORING LT4: TSH Date Value Ref Ran...
# 48356  e patient felt much more comfortable with and ...
# 48357  y Social History Narrative Divorced, 1 daughte...
# 48358   0737) O2 Device: None (Room air) (04/12/18 07...
#
#                      regex_match
# 0                     [cerebral]
# 1                       [memory]
# 2                     [dementia]
# 3      [cognition, memory, moca]
# 4            [cognition, memory]
# ...                          ...
# 48354     [cerebellar, cerebral]
# 48355        [cognition, memory]
# 48356                [cognition]
# 48357                [cognition]
# 48358                [cognition]
#
# [239629 rows x 11 columns]

# %%
df.to_excel(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\FINAL\apoe_padded_matches.xlsx", index = False)

# %%
df = pd.read_excel(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\FINAL\apoe_padded_matches.xlsx", sheet_name = "Sheet1", index_col = 0)

# %%
df['regex_sent'] = df['regex_sent'].apply(json.dumps)
df['regex_match'] = df['regex_match'].apply(json.dumps)

# %%
df.to_excel(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\FINAL\apoe_padded_matches.xlsx", index = False)

# %%
df = pd.read_excel(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\FINAL\apoe_padded_matches.xlsx", sheet_name = 'Sheet1', index_col = 0)

# %%
df
# Out:
#                MRN       EMPI  PatientEncounterID InpatientNoteTypeDSC  \
# 0      10040002098  100000272        3.076070e+09       Progress Notes
# 1      10040002098  100000272        3.076214e+09       Progress Notes
# 2      10040002098  100000272        3.242118e+09       Progress Notes
# 3      10040002098  100000272        3.322836e+09       Progress Notes
# 4      10040002098  100000272        3.325561e+09       Progress Notes
# ...            ...        ...                 ...                  ...
# 48354  10127721883  113722742        3.215952e+09       Progress Notes
# 48355  10127721883  113722742        3.217899e+09       Progress Notes
# 48356  10127721883  113722742        3.223494e+09       Progress Notes
# 48357  10127721883  113722742        3.329813e+09       Progress Notes
# 48358  10127767464  113727131        3.194125e+09    Discharge Summary
#
#            NoteID     NoteCSNID                   ContactDTS  \
# 0       471433064  4.532520e+08  2015-06-17 00:00:00.0000000
# 1       513142600  4.924833e+08  2015-07-16 00:00:00.0000000
# 2      2370049295  2.338373e+09  2019-03-14 00:00:00.0000000
# 3      4959788710  4.951007e+09  2020-12-04 00:00:00.0000000
# 4      4570521668  4.558686e+09  2020-09-18 00:00:00.0000000
# ...           ...           ...                          ...
# 48354  2123364929  2.085143e+09  2018-09-05 00:00:00.0000000
# 48355  2161398176  2.124284e+09  2018-10-03 00:00:00.0000000
# 48356  2198013886  2.161922e+09  2018-10-31 00:00:00.0000000
# 48357  4806472815  4.806423e+09  2020-11-04 00:00:00.0000000
# 48358  1935969876  1.892266e+09  2018-03-20 00:00:00.0000000
#
#                                                  NoteTXT  \
# 0      ----------------------------------------------...
# 1      ----------------------------------------------...
# 2      ----------------------------------------------...
# 3      ----------------------------------------------...
# 4      ----------------------------------------------...
# ...                                                  ...
# 48354  ----------------------------------------------...
# 48355  ----------------------------------------------...
# 48356  ----------------------------------------------...
# 48357  ----------------------------------------------...
# 48358  ----------------------------------------------...
#
#                                               regex_sent  \
# 0      "ked at HMS in the department of psychobiology...
# 1      "or lymphadenopathy. Chest: Clear to auscultat...
# 2      "ession alone in the meta-analysis. We discuss...
# 3      " ------- ing tylenol really accept for this w...
# 4      " ------- in is related to cancer. Reassuringl...
# ...                                                  ...
# 48354  " -------  pulse sequence(s). MRA of the neck ...
# 48355  " ------- ONITORING LT4: TSH Date Value Ref Ra...
# 48356  "e patient felt much more comfortable with and...
# 48357  "y Social History Narrative Divorced, 1 daught...
# 48358  " 0737) O2 Device: None (Room air) (04/12/18 0...
#
#                              regex_match
# 0                         "['cerebral']"
# 1                           "['memory']"
# 2                         "['dementia']"
# 3      "['cognition', 'memory', 'moca']"
# 4              "['cognition', 'memory']"
# ...                                  ...
# 48354       "['cerebellar', 'cerebral']"
# 48355          "['cognition', 'memory']"
# 48356                    "['cognition']"
# 48357                    "['cognition']"
# 48358                    "['cognition']"
#
# [239629 rows x 10 columns]

# %%
example.columns
# Out:
# Index(['PatientID', 'MRN', 'EMPI', 'PatientEncounterID',
#        'InpatientNoteTypeDSC', 'NoteID', 'NoteCSNID', 'ContactDTS', 'NoteTXT',
#        'regex_sent', 'regex_match'],
#       dtype='object')

# %%
df = df[['PatientID', 'MRN', 'EMPI', 'PatientEncounterID',
       'InpatientNoteTypeDSC', 'NoteID', 'NoteCSNID', 'ContactDTS', 'NoteTXT',
       'regex_sent', 'regex_match']]

# %%
df
# Out:
#        PatientID          MRN       EMPI  PatientEncounterID  \
# 0       Z6352398  10040002098  100000272        3.076070e+09
# 1       Z6352398  10040002098  100000272        3.076214e+09
# 2       Z6352398  10040002098  100000272        3.242118e+09
# 3       Z6352398  10040002098  100000272        3.322836e+09
# 4       Z6352398  10040002098  100000272        3.325561e+09
# ...          ...          ...        ...                 ...
# 48354  Z16337903  10127721883  113722742        3.215952e+09
# 48355  Z16337903  10127721883  113722742        3.217899e+09
# 48356  Z16337903  10127721883  113722742        3.223494e+09
# 48357  Z16337903  10127721883  113722742        3.329813e+09
# 48358  Z16342458  10127767464  113727131        3.194125e+09
#
#       InpatientNoteTypeDSC      NoteID     NoteCSNID  \
# 0           Progress Notes   471433064  4.532520e+08
# 1           Progress Notes   513142600  4.924833e+08
# 2           Progress Notes  2370049295  2.338373e+09
# 3           Progress Notes  4959788710  4.951007e+09
# 4           Progress Notes  4570521668  4.558686e+09
# ...                    ...         ...           ...
# 48354       Progress Notes  2123364929  2.085143e+09
# 48355       Progress Notes  2161398176  2.124284e+09
# 48356       Progress Notes  2198013886  2.161922e+09
# 48357       Progress Notes  4806472815  4.806423e+09
# 48358    Discharge Summary  1935969876  1.892266e+09
#
#                         ContactDTS  \
# 0      2015-06-17 00:00:00.0000000
# 1      2015-07-16 00:00:00.0000000
# 2      2019-03-14 00:00:00.0000000
# 3      2020-12-04 00:00:00.0000000
# 4      2020-09-18 00:00:00.0000000
# ...                            ...
# 48354  2018-09-05 00:00:00.0000000
# 48355  2018-10-03 00:00:00.0000000
# 48356  2018-10-31 00:00:00.0000000
# 48357  2020-11-04 00:00:00.0000000
# 48358  2018-03-20 00:00:00.0000000
#
#                                                  NoteTXT  \
# 0      ----------------------------------------------...
# 1      ----------------------------------------------...
# 2      ----------------------------------------------...
# 3      ----------------------------------------------...
# 4      ----------------------------------------------...
# ...                                                  ...
# 48354  ----------------------------------------------...
# 48355  ----------------------------------------------...
# 48356  ----------------------------------------------...
# 48357  ----------------------------------------------...
# 48358  ----------------------------------------------...
#
#                                               regex_sent  \
# 0      ked at HMS in the department of psychobiology ...
# 1      or lymphadenopathy. Chest: Clear to auscultati...
# 2      ession alone in the meta-analysis. We discusse...
# 3       ------- ing tylenol really accept for this we...
# 4       ------- in is related to cancer. Reassuringly...
# ...                                                  ...
# 48354   -------  pulse sequence(s). MRA of the neck w...
# 48355   ------- ONITORING LT4: TSH Date Value Ref Ran...
# 48356  e patient felt much more comfortable with and ...
# 48357  y Social History Narrative Divorced, 1 daughte...
# 48358   0737) O2 Device: None (Room air) (04/12/18 07...
#
#                      regex_match
# 0                     [cerebral]
# 1                       [memory]
# 2                     [dementia]
# 3      [cognition, memory, moca]
# 4            [cognition, memory]
# ...                          ...
# 48354     [cerebellar, cerebral]
# 48355        [cognition, memory]
# 48356                [cognition]
# 48357                [cognition]
# 48358                [cognition]
#
# [239629 rows x 11 columns]

# %% [markdown]
# # Not-Padded Matches

# %%
# df1 = pd.read_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\1\Padded_Matches\apoe_1_not_padded_matches.csv")
# df2 = pd.read_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\2\Padded_Matches\apoe_2_not_padded_matches.csv")
# df3 = pd.read_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\3\Padded_Matches\apoe_3_not_padded_matches.csv")
# df4 = pd.read_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\4\Padded_Matches\apoe_4_not_padded_matches.csv")
# df5 = pd.read_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\5\Padded_Matches\apoe_5_not_padded_matches.csv")

# %%
#frames = [df1, df2,df3, df4, df5]
df_not_padded = pd.read_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\Diversity_Sampling\not_processed_matches.csv")

# %%
example.columns
# Out:
# Index(['PatientID', 'MRN', 'EMPI', 'PatientEncounterID',
#        'InpatientNoteTypeDSC', 'NoteID', 'NoteCSNID', 'ContactDTS', 'NoteTXT',
#        'regex_sent', 'regex_match'],
#       dtype='object')

# %%
df_not_padded.columns, len(df_not_padded)
# Out:
# (Index(['PatientID', 'MRN', 'EMPI', 'PatientEncounterID',
#         'InpatientNoteTypeDSC', 'NoteID', 'NoteCSNID', 'ContactDTS', 'NoteTXT',
#         'regex_sent', 'regex_match'],
#        dtype='object'),
#  235715)

# %%
df_not_padded = df_not_padded.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'Unnamed: 0.1.1.1', 'EncounterTypeDSC'])

# %%
df_not_padded = df_not_padded.drop(columns = ['Unnamed: 0.1.1.1.1', 'Unnamed: 0.1.1.1.1.1'])

# %%
df
# Out:
#         PatientID          MRN       EMPI  PatientEncounterID  \
# 0        Z6398203      2579886  100030990        3.284218e+09
# 1        Z6398203      2579886  100030990        3.340324e+09
# 2        Z6398203      2579886  100030990        3.340837e+09
# 3        Z6398203      2579886  100030990        3.347308e+09
# 4        Z6398230      1577089  100030999        3.181851e+09
# ...           ...          ...        ...                 ...
# 274210  Z16320629  10127549029  113705759        3.285425e+09
# 274211  Z16320629  10127549029  113705759        3.305416e+09
# 274212  Z16320629  10127549029  113705759        3.327430e+09
# 274213  Z16320629  10127549029  113705759        3.349755e+09
# 274214  Z16323433  10127577079  113708529        3.196619e+09
#
#        InpatientNoteTypeDSC      NoteID     NoteCSNID  \
# 0            Progress Notes  5786184612  5.783659e+09
# 1            Progress Notes  4962623319  5.111476e+09
# 2            Progress Notes  5881291037  5.892214e+09
# 3                    Letter  5452283829  5.447225e+09
# 4            Progress Notes  1794875152  1.747131e+09
# ...                     ...         ...           ...
# 274210       Progress Notes  3960511043  3.943607e+09
# 274211       Progress Notes  4585859437  4.574134e+09
# 274212       Progress Notes  5203067949  5.224024e+09
# 274213       Progress Notes  5673786544  5.670392e+09
# 274214       Progress Notes  1939524875  1.895938e+09
#
#                          ContactDTS  \
# 0       2021-05-10 00:00:00.0000000
# 1       2020-12-04 00:00:00.0000000
# 2       2021-05-25 00:00:00.0000000
# 3       2021-03-12 00:00:00.0000000
# 4       2017-12-19 00:00:00.0000000
# ...                             ...
# 274210  2020-04-28 00:00:00.0000000
# 274211  2020-09-22 00:00:00.0000000
# 274212  2021-01-25 00:00:00.0000000
# 274213  2021-04-20 00:00:00.0000000
# 274214  2018-04-16 00:00:00.0000000
#
#                                                   NoteTXT  \
# 0       ----------------------------------------------...
# 1       ----------------------------------------------...
# 2       ----------------------------------------------...
# 3       ----------------------------------------------...
# 4       ----------------------------------------------...
# ...                                                   ...
# 274210  ----------------------------------------------...
# 274211  ----------------------------------------------...
# 274212  ----------------------------------------------...
# 274213  ----------------------------------------------...
# 274214  ----------------------------------------------...
#
#                                                regex_sent    regex_match
# 0       'on and coordination, normal speech. Psych: Be...  ['cognition']
# 1       ' normal coordination and gait. Psych: Alert a...  ['cognition']
# 2       ' other lesions. Normal turgor. Psych: Alert a...  ['cognition']
# 3       'on and coordination, normal speech. Psych: Be...  ['cognition']
# 4       'tter with markedly diminished right sided ret...     ['memory']
# ...                                                   ...            ...
# 274210  "'she took a break' and wants to discuss with ...     ["memory"]
# 274211  "all of her medications, including aspirin. De...     ["memory"]
# 274212  "Patient, Chart, daughter Olga Mode of contact...  ["cognition"]
# 274213  "Patient, Chart, daughter Olga Mode of contact...  ["cognition"]
# 274214  "cyanosis or edema. Neurological exam: Nonfoca...  ["Cognition"]
#
# [274215 rows x 11 columns]

# %%
df_not_padded.columns
# Out:
# Index(['index', 'EMPI', 'MRN', 'PatientID', 'PatientEncounterID', 'ContactDTS',
#        'NoteID', 'InpatientNoteTypeDSC', 'buckets', 'NoteCSNID', 'LineNBR',
#        'NoteTXT', 'regex_location', 'regex_sent', 'regex_match', 'match_count',
#        'pruned_regex_location', 'merged_row_location', 'merged_regex_sent',
#        'merged_regex_match', 'padded_merged_row_location',
#        'padded_merged_regex_sent', 'padded_char_count', 'note_char_count',
#        'PCPID', 'EncounterEpicProviderID', 'pcp_flag', 'SpecialtyDSC',
#        'padded_regex_match'],
#       dtype='object')

# %%
df_not_padded = df_not_padded.drop(columns = ['buckets', 'LineNBR', 'regex_location', 'regex_sent', 'regex_match', 'match_count','pruned_regex_location', 'merged_row_location','merged_regex_match', 'padded_char_count'])

# %%
df_not_padded.columns
# Out:
# Index(['index', 'EMPI', 'MRN', 'PatientID', 'PatientEncounterID', 'ContactDTS',
#        'NoteID', 'InpatientNoteTypeDSC', 'NoteCSNID', 'NoteTXT',
#        'merged_regex_sent', 'padded_merged_row_location',
#        'padded_merged_regex_sent', 'note_char_count', 'PCPID',
#        'EncounterEpicProviderID', 'pcp_flag', 'SpecialtyDSC',
#        'padded_regex_match'],
#       dtype='object')

# %%
df_not_padded = df_not_padded.drop(columns = ['note_char_count', 'PCPID',
       'EncounterEpicProviderID', 'pcp_flag', 'SpecialtyDSC',])

# %%
df_not_padded = df_not_padded.drop(columns = ['padded_merged_row_location'])

# %%
df_not_padded = df_not_padded.drop(columns = ['index'])

# %%
(df_not_padded.columns)
# Out:
# Index(['EMPI', 'MRN', 'PatientID', 'PatientEncounterID', 'ContactDTS',
#        'NoteID', 'InpatientNoteTypeDSC', 'NoteCSNID', 'NoteTXT',
#        'merged_regex_sent', 'padded_merged_regex_sent', 'padded_regex_match'],
#       dtype='object')

# %%
df_not_padded = df_not_padded.drop(columns = ['merged_regex_sent'])

# %%
example.columns
# Out:
# Index(['PatientID', 'MRN', 'EMPI', 'PatientEncounterID',
#        'InpatientNoteTypeDSC', 'NoteID', 'NoteCSNID', 'ContactDTS', 'NoteTXT',
#        'regex_sent', 'regex_match'],
#       dtype='object')

# %%
df_not_padded
# Out:
#            EMPI          MRN  PatientID  PatientEncounterID  \
# 0     100000272  10040002098   Z6352398        3.242118e+09
# 1     100000894       200766   Z6352922        3.181499e+09
# 2     100001150  10027033512   Z6353136        3.018789e+09
# 3     100001521  10040011735   Z6353461        3.172504e+09
# 4     100001873  10040014499   Z6353764        3.165983e+09
# ...         ...          ...        ...                 ...
# 5004  101886663     15974728   Z6566087        3.019130e+09
# 5005  101892417      1205814   Z6593900        3.317829e+09
# 5006  102238452  10033260075   Z8801390        3.186800e+09
# 5007  102424707  10022003700   Z9965570        3.306047e+09
# 5008  102656517  10026917731  Z11573515        3.292964e+09
#
#                        ContactDTS      NoteID InpatientNoteTypeDSC  \
# 0     2019-03-14 00:00:00.0000000  2370049295       Progress Notes
# 1     2018-03-28 00:00:00.0000000  1916263837       Progress Notes
# 2     2015-01-09 00:00:00.0000000   267681869    Discharge Summary
# 3     2017-10-03 00:00:00.0000000  1682366001       Progress Notes
# 4     2018-02-07 00:00:00.0000000  1853759390       Progress Notes
# ...                           ...         ...                  ...
# 5004  2014-08-07 00:00:00.0000000   267890258    Discharge Summary
# 5005  2020-07-29 00:00:00.0000000  4335598103                  NaN
# 5006  2018-01-22 00:00:00.0000000  1846710034       Progress Notes
# 5007  2020-05-08 00:00:00.0000000  4028154201       Progress Notes
# 5008  2020-02-03 00:00:00.0000000  3649301059             Consults
#
#          NoteCSNID                                            NoteTXT  \
# 0     2.338373e+09  ----------------------------------------------...
# 1     1.871982e+09  ----------------------------------------------...
# 2     2.555255e+08  ----------------------------------------------...
# 3     1.631850e+09  ----------------------------------------------...
# 4     1.807703e+09  ----------------------------------------------...
# ...            ...                                                ...
# 5004  2.557313e+08  ----------------------------------------------...
# 5005  4.321849e+09  ----------------------------------------------...
# 5006  1.800448e+09  ----------------------------------------------...
# 5007  4.011889e+09  ----------------------------------------------...
# 5008  3.629660e+09  ----------------------------------------------...
#
#                                padded_merged_regex_sent  \
# 0     ession alone in the meta-analysis. We discusse...
# 1      ------- sis over her R bra strap, which was i...
# 2      ------- l obstruction ASSOCIATED DIAGNOSES Sm...
# 3      -------  (156 lb) 09/19/17 71.4 kg (157 lb 6....
# 4     ut answer. Optho notes from recent outpatient ...
# ...                                                 ...
# 5004  er lisinopril and dyazide on discharge. Please...
# 5005  ----------------------------------------------...
# 5006  ding w/ close S and grab bar, HHSH Dressing: U...
# 5007  dressing with LHAE. Pt able to improve perform...
# 5008   ------- n eval, anticipate Min A for UBB LB: ...
#
#                         padded_regex_match
# 0                             ['dementia']
# 1           ['dementia', 'memory', 'moca']
# 2     ['dementia', 'cognitive impairment']
# 3                ['dementia', 'cognition']
# 4                             ['dementia']
# ...                                    ...
# 5004                   ['cognition', 'ad']
# 5005          ['dementia', 'memory', 'ad']
# 5006                  ['cognition', 'lbd']
# 5007                     ['memory', 'lbd']
# 5008        ['cognition', 'memory', 'lbd']
#
# [5009 rows x 11 columns]

# %%
df_not_padded.columns = ['EMPI', 'MRN', 'PatientID', 'PatientEncounterID', 'ContactDTS',
       'NoteID', 'InpatientNoteTypeDSC', 'NoteCSNID', 'NoteTXT', 'regex_sent', 'regex_match']

# %%
df_not_padded = df_not_padded[['PatientID', 'MRN', 'EMPI', 'PatientEncounterID',
       'InpatientNoteTypeDSC', 'NoteID', 'NoteCSNID', 'ContactDTS', 'NoteTXT',
       'regex_sent', 'regex_match']]

# %%
df_not_padded
# Out:
#       PatientID          MRN       EMPI  PatientEncounterID  \
# 0      Z6352398  10040002098  100000272        3.242118e+09
# 1      Z6352922       200766  100000894        3.181499e+09
# 2      Z6353136  10027033512  100001150        3.018789e+09
# 3      Z6353461  10040011735  100001521        3.172504e+09
# 4      Z6353764  10040014499  100001873        3.165983e+09
# ...         ...          ...        ...                 ...
# 5004   Z6566087     15974728  101886663        3.019130e+09
# 5005   Z6593900      1205814  101892417        3.317829e+09
# 5006   Z8801390  10033260075  102238452        3.186800e+09
# 5007   Z9965570  10022003700  102424707        3.306047e+09
# 5008  Z11573515  10026917731  102656517        3.292964e+09
#
#      InpatientNoteTypeDSC      NoteID     NoteCSNID  \
# 0          Progress Notes  2370049295  2.338373e+09
# 1          Progress Notes  1916263837  1.871982e+09
# 2       Discharge Summary   267681869  2.555255e+08
# 3          Progress Notes  1682366001  1.631850e+09
# 4          Progress Notes  1853759390  1.807703e+09
# ...                   ...         ...           ...
# 5004    Discharge Summary   267890258  2.557313e+08
# 5005                  NaN  4335598103  4.321849e+09
# 5006       Progress Notes  1846710034  1.800448e+09
# 5007       Progress Notes  4028154201  4.011889e+09
# 5008             Consults  3649301059  3.629660e+09
#
#                        ContactDTS  \
# 0     2019-03-14 00:00:00.0000000
# 1     2018-03-28 00:00:00.0000000
# 2     2015-01-09 00:00:00.0000000
# 3     2017-10-03 00:00:00.0000000
# 4     2018-02-07 00:00:00.0000000
# ...                           ...
# 5004  2014-08-07 00:00:00.0000000
# 5005  2020-07-29 00:00:00.0000000
# 5006  2018-01-22 00:00:00.0000000
# 5007  2020-05-08 00:00:00.0000000
# 5008  2020-02-03 00:00:00.0000000
#
#                                                 NoteTXT  \
# 0     ----------------------------------------------...
# 1     ----------------------------------------------...
# 2     ----------------------------------------------...
# 3     ----------------------------------------------...
# 4     ----------------------------------------------...
# ...                                                 ...
# 5004  ----------------------------------------------...
# 5005  ----------------------------------------------...
# 5006  ----------------------------------------------...
# 5007  ----------------------------------------------...
# 5008  ----------------------------------------------...
#
#                                              regex_sent  \
# 0     ession alone in the meta-analysis. We discusse...
# 1      ------- sis over her R bra strap, which was i...
# 2      ------- l obstruction ASSOCIATED DIAGNOSES Sm...
# 3      -------  (156 lb) 09/19/17 71.4 kg (157 lb 6....
# 4     ut answer. Optho notes from recent outpatient ...
# ...                                                 ...
# 5004  er lisinopril and dyazide on discharge. Please...
# 5005  ----------------------------------------------...
# 5006  ding w/ close S and grab bar, HHSH Dressing: U...
# 5007  dressing with LHAE. Pt able to improve perform...
# 5008   ------- n eval, anticipate Min A for UBB LB: ...
#
#                                regex_match
# 0                             ['dementia']
# 1           ['dementia', 'memory', 'moca']
# 2     ['dementia', 'cognitive impairment']
# 3                ['dementia', 'cognition']
# 4                             ['dementia']
# ...                                    ...
# 5004                   ['cognition', 'ad']
# 5005          ['dementia', 'memory', 'ad']
# 5006                  ['cognition', 'lbd']
# 5007                     ['memory', 'lbd']
# 5008        ['cognition', 'memory', 'lbd']
#
# [5009 rows x 11 columns]

# %%
df_not_padded['regex_sent'] = df_not_padded['regex_sent'].apply(json.dumps)
df_not_padded['regex_match'] = df_not_padded['regex_match'].apply(json.dumps)

# %%
merged = df_not_padded #pd.concat([df, df_not_padded])

# %%
merged
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a2c3934d2c59> in <module>
# ----> 1 merged
#
# NameError: name 'merged' is not defined

# %%
drop = [100566134,
 101272386,
 103302871,
 103401919,
 104131445,
 104434122,
 104846067,
 105444588,
 106594083,
 106950781,
 107158726,
 107359494,
 110961570,
 111505997,
 100141139,
 100274613,
 100344755,
 100355466,
 100617631,
 100855298,
 101766574,
 101770739,
 101959132,
 102020367,
 102470097,
 103029314,
 103040962,
 103097401,
 103789921,
 104297481,
 104390508,
 104772819,
 105537030,
 105807236,
 108951869,
 111132607,
 111172213]

# %%
x = merged
merged_clone = merged

# %%
for i in range(len(drop)):
    x = merged_clone[merged_clone["EMPI"] != drop[i]]
    merged_clone = x

# %%
merged = merged_clone

# %%
merged["ContactDTS"] = pd.to_datetime(merged["ContactDTS"]).dt.strftime('%Y-%m-%d')

# %%
merged
# Out:
#       PatientID          MRN       EMPI  PatientEncounterID  \
# 0      Z6352398  10040002098  100000272        3.242118e+09
# 1      Z6352922       200766  100000894        3.181499e+09
# 2      Z6353136  10027033512  100001150        3.018789e+09
# 3      Z6353461  10040011735  100001521        3.172504e+09
# 4      Z6353764  10040014499  100001873        3.165983e+09
# ...         ...          ...        ...                 ...
# 5004   Z6566087     15974728  101886663        3.019130e+09
# 5005   Z6593900      1205814  101892417        3.317829e+09
# 5006   Z8801390  10033260075  102238452        3.186800e+09
# 5007   Z9965570  10022003700  102424707        3.306047e+09
# 5008  Z11573515  10026917731  102656517        3.292964e+09
#
#      InpatientNoteTypeDSC      NoteID     NoteCSNID  ContactDTS  \
# 0          Progress Notes  2370049295  2.338373e+09  2019-03-14
# 1          Progress Notes  1916263837  1.871982e+09  2018-03-28
# 2       Discharge Summary   267681869  2.555255e+08  2015-01-09
# 3          Progress Notes  1682366001  1.631850e+09  2017-10-03
# 4          Progress Notes  1853759390  1.807703e+09  2018-02-07
# ...                   ...         ...           ...         ...
# 5004    Discharge Summary   267890258  2.557313e+08  2014-08-07
# 5005                  NaN  4335598103  4.321849e+09  2020-07-29
# 5006       Progress Notes  1846710034  1.800448e+09  2018-01-22
# 5007       Progress Notes  4028154201  4.011889e+09  2020-05-08
# 5008             Consults  3649301059  3.629660e+09  2020-02-03
#
#                                                 NoteTXT  \
# 0     ----------------------------------------------...
# 1     ----------------------------------------------...
# 2     ----------------------------------------------...
# 3     ----------------------------------------------...
# 4     ----------------------------------------------...
# ...                                                 ...
# 5004  ----------------------------------------------...
# 5005  ----------------------------------------------...
# 5006  ----------------------------------------------...
# 5007  ----------------------------------------------...
# 5008  ----------------------------------------------...
#
#                                              regex_sent  \
# 0     "ession alone in the meta-analysis. We discuss...
# 1     " ------- sis over her R bra strap, which was ...
# 2     " ------- l obstruction ASSOCIATED DIAGNOSES S...
# 3     " -------  (156 lb) 09/19/17 71.4 kg (157 lb 6...
# 4     "ut answer. Optho notes from recent outpatient...
# ...                                                 ...
# 5004  "er lisinopril and dyazide on discharge. Pleas...
# 5005  "---------------------------------------------...
# 5006  "ding w/ close S and grab bar, HHSH Dressing: ...
# 5007  "dressing with LHAE. Pt able to improve perfor...
# 5008  " ------- n eval, anticipate Min A for UBB LB:...
#
#                                  regex_match
# 0                             "['dementia']"
# 1           "['dementia', 'memory', 'moca']"
# 2     "['dementia', 'cognitive impairment']"
# 3                "['dementia', 'cognition']"
# 4                             "['dementia']"
# ...                                      ...
# 5004                   "['cognition', 'ad']"
# 5005          "['dementia', 'memory', 'ad']"
# 5006                  "['cognition', 'lbd']"
# 5007                     "['memory', 'lbd']"
# 5008        "['cognition', 'memory', 'lbd']"
#
# [5009 rows x 11 columns]

# %%
merged['regex_sent'] = merged['regex_sent'].apply(json.dumps)
merged['regex_match'] = merged['regex_match'].apply(json.dumps)

# %%
merged = merged[:1000]

# %%
merged.to_excel(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\Diversity_Sampling\5000_SLAT_import_7_19.xlsx", index = False)

# %%
merged["ContactDTS"] = pd.to_datetime(merged["ContactDTS"]).dt.strftime('%Y-%m-%d')

# %%
merged.to_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\FINAL\SLAT_dataset_7_14.csv", index = False)

# %%
df.to_excel(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\FINAL\apoe_not_padded_matches.xlsx", index = False)

# %%
snippet = pd.read_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\FINAL\SLAT_dataset_7_14.csv")

# %%
snippet = snippet[:1000]

# %%
snippet
# Out:
#              MRN       EMPI  PatientEncounterID InpatientNoteTypeDSC  \
# 0    10040002098  100000272        3.076070e+09       Progress Notes
# 1    10040002098  100000272        3.076214e+09       Progress Notes
# 2    10040002098  100000272        3.242118e+09       Progress Notes
# 3    10040002098  100000272        3.322836e+09       Progress Notes
# 4    10040002098  100000272        3.325561e+09       Progress Notes
# ..           ...        ...                 ...                  ...
# 995  10040097643  100008870        3.188221e+09         Plan of Care
# 996  10040097643  100008870        3.188221e+09             Consults
# 997  10040097643  100008870        3.188221e+09             Consults
# 998  10040097643  100008870        3.188221e+09       Progress Notes
# 999  10040097643  100008870        3.188221e+09       Progress Notes
#
#          NoteID     NoteCSNID  ContactDTS  \
# 0     471433064  4.532520e+08  2015-06-17
# 1     513142600  4.924833e+08  2015-07-16
# 2    2370049295  2.338373e+09  2019-03-14
# 3    4959788710  4.951007e+09  2020-12-04
# 4    4570521668  4.558686e+09  2020-09-18
# ..          ...           ...         ...
# 995  1846564690  1.800569e+09  2018-02-01
# 996  1846622314  1.800356e+09  2018-02-01
# 997  1846733081  1.800505e+09  2018-02-01
# 998  1847368580  1.801464e+09  2018-02-01
# 999  1847947923  1.801725e+09  2018-02-01
#
#                                                NoteTXT  \
# 0    ----------------------------------------------...
# 1    ----------------------------------------------...
# 2    ----------------------------------------------...
# 3    ----------------------------------------------...
# 4    ----------------------------------------------...
# ..                                                 ...
# 995  ----------------------------------------------...
# 996  ----------------------------------------------...
# 997  ----------------------------------------------...
# 998  ----------------------------------------------...
# 999  ----------------------------------------------...
#
#                                             regex_sent  \
# 0    "ked at HMS in the department of psychobiology...
# 1    "or lymphadenopathy. Chest: Clear to auscultat...
# 2    "ession alone in the meta-analysis. We discuss...
# 3    " ------- ing tylenol really accept for this w...
# 4    " ------- in is related to cancer. Reassuringl...
# ..                                                 ...
# 995  "elf-care Deficit - Neurological Condition - A...
# 996  "---------------------------------------------...
# 997  " -------  Deferred- Requiring nursing assista...
# 998  "---------------------------------------------...
# 999  "---------------------------------------------...
#
#                            regex_match
# 0                       "['cerebral']"
# 1                         "['memory']"
# 2                       "['dementia']"
# 3    "['cognition', 'memory', 'moca']"
# 4            "['cognition', 'memory']"
# ..                                 ...
# 995                     "['cerebral']"
# 996                   "['cerebellar']"
# 997                   "['cerebellar']"
# 998       "['cerebellar', 'cerebral']"
# 999                   "['cerebellar']"
#
# [1000 rows x 10 columns]

# %%
snippet.to_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\SLAT_snippet.csv", index = False)
