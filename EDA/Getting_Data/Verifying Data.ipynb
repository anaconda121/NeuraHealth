# %%
import pandas as pd
import pandas.io.sql as psql
import os
import sys
from datetime import date
current_date = date.today()
#%load_ext autotime
import re
import csv
import pandas as pd
import numpy as np
import os
from glob import glob
from tqdm import tqdm
import matplotlib.pyplot as plt
#from matplotlib_venn import venn2, venn3
import warnings
import time
import datetime as dt
import itertools
from more_itertools import unique_everseen
warnings.filterwarnings("ignore")
#import pandasql as ps
import seaborn as sns
import json
from ast import literal_eval
import ast

# %%
total = pd.read_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\total_summary_stats_updated_7_6_2021.csv")

# %%
total
# Out:
#        Unnamed: 0  Unnamed: 0.1       EMPI  Unique_Encounters
# 0               0             0  100000272                 10
# 1               1             1  100000521                  6
# 2               2             2  100000623                  5
# 3               3             3  100000894                  7
# 4               4             4  100000920                  3
# ...           ...           ...        ...                ...
# 16956        3913          3913  113714475                  7
# 16957        3914          3914  113716850                  4
# 16958        3915          3915  113722466                  5
# 16959        3916          3916  113722742                 12
# 16960        3917          3917  113727131                  1
#
# [16961 rows x 4 columns]

# %%
one = total[total["Unique_Encounters"] == 1]
head_100 = one[:100]

# %%
m1 = pd.read_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\1\apoe_1_matches_updated_pruned.csv")
m2 = pd.read_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\2\apoe_2_matches_updated_pruned.csv")
m3 = pd.read_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\3\apoe_3_matches_updated_pruned.csv")
m4 = pd.read_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\4\apoe_4_matches_updated_pruned.csv")
m5 = pd.read_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\5\apoe_5_matches_updated_pruned.csv")

# %%
frames = [m1, m2, m3, m4, m5]
merged = pd.concat(frames)

# %%
merged[merged['EMPI'] == 100009747]
# Out:
#       Unnamed: 0  Unnamed: 0.1       EMPI      MRN PatientID  \
# 1314        5257        5257.0  100009747  3919528  Z6360516
#
#       PatientEncounterID                   ContactDTS    EncounterTypeDSC  \
# 1314        3.283811e+09  2019-12-06 00:00:00.0000000  Hospital Encounter
#
#           NoteID InpatientNoteTypeDSC  ...     NoteCSNID  LineNBR  \
# 1314  3341615619    ED Provider Notes  ...  3.322521e+09      1.0
#
#                                                 NoteTXT  \
# 1314  ----------------------------------------------...
#
#                     regex_location  \
# 1314  [(7209, 7219), (8892, 8901)]
#
#                                              regex_sent     regex_match  \
# 1314  'story of trauma, doubt subdural or epidural h...  ['cerebellar']
#
#      match_count  pruned_regex_location           merged_row_location  \
# 1314           1           [(100, 111)]  [(7109, 7319), (8792, 9001)]
#
#                                       merged_regex_sent
# ...

# %%
merged_2 = pd.merge(head_100, merged, left_on='EMPI', right_on='EMPI', how='left')
merged_2
# Out:
#      Unnamed: 0_x  Unnamed: 0.1_x       EMPI  Unique_Encounters  Unnamed: 0_y  \
# 0              50              50  100009747                  1          5257
# 1              55              55  100010042                  1          5524
# 2              55              55  100010042                  1          5528
# 3              59              59  100010311                  1          5743
# 4             154             154  100023305                  1         16079
# ..            ...             ...        ...                ...           ...
# 132          1386            1386  100147829                  1        145342
# 133          1421            1421  100151713                  1        149746
# 134          1438            1438  100153783                  1        151607
# 135          1442            1442  100154138                  1        151828
# 136          1456            1456  100155399                  1        152985
#
# ...

# %%
merged_2["NoteID"].nunique() #137 is b/c of multiple notes per encounter
# Out:
# 137

# %%
merged_2.columns
# Out:
# Index(['Unnamed: 0_x', 'Unnamed: 0.1_x', 'EMPI', 'Unique_Encounters',
#        'Unnamed: 0_y', 'Unnamed: 0.1_y', 'MRN', 'PatientID',
#        'PatientEncounterID', 'ContactDTS', 'EncounterTypeDSC', 'NoteID',
#        'InpatientNoteTypeDSC', 'buckets', 'NoteCSNID', 'LineNBR', 'NoteTXT',
#        'regex_location', 'regex_sent', 'regex_match', 'match_count',
#        'pruned_regex_location', 'merged_row_location', 'merged_regex_sent'],
#       dtype='object')

# %%
merged_2.to_csv(r"C:\Users\MIND_DS\Dropbox (Partners HealthCare)\NLP\Tanish\BigDataSets\Regex_match\100_patients_verification.csv")

# %%
113676821 113678823 113681718

# %%
merged[merged['EMPI'] == 113676821] #suppoed to have 2 unique encounter ids
# Out:
#        Unnamed: 0  Unnamed: 0.1       EMPI          MRN  PatientID  \
# 60534      277014           NaN  113676821  10127255791  Z16291324
# 60535      277016           NaN  113676821  10127255791  Z16291324
#
#        PatientEncounterID                   ContactDTS EncounterTypeDSC  \
# 60534        3.187025e+09  2018-02-06 00:00:00.0000000     Office Visit
# 60535        3.188836e+09  2018-02-27 00:00:00.0000000     Office Visit
#
#            NoteID InpatientNoteTypeDSC  ...     NoteCSNID  LineNBR  \
# 60534  1851722182       Progress Notes  ...  1.807318e+09      1.0
# 60535  1878506152       Progress Notes  ...  1.834913e+09      1.0
#
#                                                  NoteTXT  \
# 60534  ----------------------------------------------...
# 60535  ----------------------------------------------...
#
#                      regex_location  \
# 60534  [(5255, 5261), (6069, 6079)]
# 60535  [(8397, 8403), (9209, 9219)]
#
# ...

# %%
merged[merged['EMPI'] == 113678823] #suppoed to have 3 unique encounter ids
# Out:
#        Unnamed: 0  Unnamed: 0.1       EMPI      MRN  PatientID  \
# 60536      277018           NaN  113678823  6260013  Z16293330
# 60537      277020           NaN  113678823  6260013  Z16293330
# 60538      277027           NaN  113678823  6260013  Z16293330
#
#        PatientEncounterID                   ContactDTS    EncounterTypeDSC  \
# 60536        3.187727e+09  2018-01-29 00:00:00.0000000  Hospital Encounter
# 60537        3.203611e+09  2018-07-20 00:00:00.0000000        Office Visit
# 60538        3.361089e+09  2021-03-22 00:00:00.0000000  Hospital Encounter
#
#            NoteID InpatientNoteTypeDSC  ...     NoteCSNID  LineNBR  \
# 60536  1878616721    Discharge Summary  ...  1.833265e+09      1.0
# 60537  2064564590       Progress Notes  ...  2.024623e+09      1.0
# 60538  5630935490    Discharge Summary  ...  5.627199e+09      1.0
#
#                                                  NoteTXT    regex_location  \
# ...

# %%
merged[merged['EMPI'] == 113681718] #suppoed to have 3 unique encounter ids
# Out:
#        Unnamed: 0  Unnamed: 0.1       EMPI          MRN  PatientID  \
# 60539      277030           NaN  113681718  10127305273  Z16296267
# 60540      277033           NaN  113681718  10127305273  Z16296267
# 60541      277039           NaN  113681718  10127305273  Z16296267
#
#        PatientEncounterID                   ContactDTS EncounterTypeDSC  \
# 60539        3.098939e+09  2015-12-15 00:00:00.0000000     Office Visit
# 60540        3.184374e+09  2018-07-03 00:00:00.0000000     Office Visit
# 60541        3.356283e+09  2021-03-17 00:00:00.0000000     Office Visit
#
#            NoteID InpatientNoteTypeDSC  ...     NoteCSNID  LineNBR  \
# 60539   724171123       Progress Notes  ...  6.949376e+08      1.0
# 60540  2042391177       Progress Notes  ...  2.001793e+09      1.0
# 60541  5446039114       Progress Notes  ...  5.440928e+09      1.0
#
#                                                  NoteTXT  \
# 60539  ----------------------------------------------...
# ...
